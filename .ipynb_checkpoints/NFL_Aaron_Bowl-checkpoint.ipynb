# %% [markdown]
# ## Aaron Bowl

# %% [markdown]
# On 1/16/21 in the first game of the NFL Divisional Playoffs, the Green Bay Packers will face the Los Angeles Rams.
# These teams represent the NFL's top ranked defense (Rams) and offense (Packers).
# Interestingly the best player on each team is named Aaron. Aaron Rodgers is possibly the best quarterback in football and he is one of the hot favorites for this year's Most Valuable Player award. Aaron Donald is one of the best ever to play his position. He is one of three favorites for this year's Defensive Player of Year. Throw in the Packer's running back Aaron Jones as well. No matter how this game turns out it will be highly influenced by one the Aarons. That's why I'm calling it the Aaron Bowl

# %% [markdown]
# ### Loading Data

# %% [markdown]
# Data sources: <br>
# https://www.kaggle.com/c/nfl-big-data-bowl-2020 <br>
# https://www.nfl.com/stats/player-stats/ <br>
# https://www.pro-football-reference.com/

# %% [markdown]
# Note:
# Unfortunately, none of these sources of data are completely open-source.
# Kaggle allows “Competition Use, Non-Commercial, and Academic Use Only.” NFL.com data is “solely for your own individual non-commercial and informational purposes only.” Pro Football Reference has the most open data, “we encourage the sharing and reuse of data and statistics our users find on our Site” but warns not “to copy a materially significant portion of our data” — so no scraping.

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import NFL stats
df = pd.read_csv (r'NFL_players.csv')
df.head()
# Out:
#            Player    First      Last Suffix         Current Team Position  \
# 0   Mario Addison    Mario   Addison    NaN        Buffalo Bills       DE
# 1      Zach Allen     Zach     Allen    NaN    Arizona Cardinals       DE
# 2    Bradlee Anae  Bradlee      Anae    NaN       Dallas Cowboys       DE
# 3  Henry Anderson    Henry  Anderson    NaN        New York Jets       DE
# 4   Arik Armstead     Arik  Armstead    NaN  San Francisco 49ers       DE
#
#     Group  height  weight   birthdate         college  Pass_Yd  QB_rating  \
# 0  Tackle    75.0   260.0  09/06/1987            Troy      NaN        NaN
# 1  Tackle    77.0   285.0  08/20/1997  Boston College      NaN        NaN
# 2  Tackle     NaN     NaN         NaN             NaN      NaN        NaN
# 3  Tackle    78.0   301.0  08/03/1991        Stanford      NaN        NaN
# 4  Tackle    79.0   292.0  11/15/1993          Oregon      NaN        NaN
#
#    Pass_TD  Rush_Yd  Receive_Yd  Receive_TD  Sacks
# 0      NaN      NaN         NaN         NaN    5.0
# 1      NaN      NaN         NaN         NaN    2.0
# 2      NaN      NaN         NaN         NaN    NaN
# 3      NaN      NaN         NaN         NaN    0.5
# 4      NaN      NaN         NaN         NaN    3.5

# %% [markdown]
# ### Investigate the Data

# %%
df.describe()
# Out:
#            height      weight      Pass_Yd   QB_rating    Pass_TD  \
# count  656.000000  656.000000    38.000000   38.000000  38.000000
# mean    74.237805  242.364329  2965.342105   92.455263  20.447368
# std      2.657239   38.642537  1347.477970   13.466368  12.426426
# min     66.000000  170.000000   624.000000   54.500000   2.000000
# 25%     73.000000  213.000000  1902.750000   81.250000   9.250000
# 50%     75.000000  238.000000  2942.500000   94.200000  18.000000
# 75%     76.000000  265.000000  4152.500000  102.000000  30.000000
# max     80.000000  366.000000  4823.000000  121.500000  48.000000
#
#            Rush_Yd   Receive_Yd  Receive_TD       Sacks
# count   111.000000   364.000000  364.000000  225.000000
# mean    460.234234   328.719780    2.153846    3.513333
# std     342.629430   324.742973    2.747092    2.986547
# min      99.000000     4.000000    0.000000    0.500000
# 25%     197.500000    80.750000    0.000000    1.000000
# 50%     367.000000   208.500000    1.000000    2.500000
# 75%     649.000000   472.500000    3.000000    5.000000
# max    2027.000000  1535.000000   18.000000   15.000000

# %%
df.dtypes
# Out:
# Player           object
# First            object
# Last             object
# Suffix           object
# Current Team     object
# Position         object
# Group            object
# height          float64
# weight          float64
# birthdate        object
# college          object
# Pass_Yd         float64
# QB_rating       float64
# Pass_TD         float64
# Rush_Yd         float64
# Receive_Yd      float64
# Receive_TD      float64
# Sacks           float64
# dtype: object

# %%
# convert birthdate to date time
df['birthdate'] = pd.to_datetime(df['birthdate'])

# %% [markdown]
# ### Notes on the Data

# %% [markdown]
# There are six active Aarons in the NFL. Aaron Donald, Aaron Rodgers, Aaron Jones, Aaron Lynch, Aaron Brewer and Aaron Stinnie.
# In this analysis I'm am focusing on seven positions: QB, WR, RB, TE (offense) and DE, DT, OLB (defense). These positions earn the bulk of measurable statistics on Passing, Rushing, Receiving and Sacks. There are certainly other measures - but these are what I am primarily focussed on.
# * QB rating has a minimum of 100 attempts
# * Receiving yards is after a minimum of 10 receptions
# * There are four Aarons in QB, WR, RB, TE, DE, DT, OLB positions

# %%
# Active Aarons
df_Aaron = df[df['First'] == 'Aaron']
df_Aaron
# Out:
#             Player  First     Last Suffix          Current Team Position  \
# 36    Aaron Donald  Aaron   Donald    NaN      Los Angeles Rams       DE
# 320    Aaron Lynch  Aaron    Lynch    NaN  Jacksonville Jaguars      OLB
# 425  Aaron Rodgers  Aaron  Rodgers    NaN     Green Bay Packers       QB
# 532    Aaron Jones  Aaron    Jones    NaN     Green Bay Packers       RB
#
#        Group  height  weight  birthdate        college  Pass_Yd  QB_rating  \
# 36    Tackle    73.0   280.0 1991-05-23     Pittsburgh      NaN        NaN
# 320   Tackle    77.0   285.0 1993-02-08  South Florida      NaN        NaN
# 425  Passing    74.0   225.0 1983-12-02     California   4299.0      121.5
# 532     Rush    69.0   208.0 1994-12-02  Texas-El Paso      NaN        NaN
#
#      Pass_TD  Rush_Yd  Receive_Yd  Receive_TD  Sacks
# 36       NaN      NaN         NaN         NaN   13.5
# 320      NaN      NaN         NaN         NaN    1.0
# 425     48.0    149.0         NaN         NaN    NaN
# 532      NaN   1104.0       355.0         2.0    NaN

# %% [markdown]
# ### QB Rating

# %%
df.sort_values(by=['QB_rating'], ascending=False).head()
# Out:
#               Player    First       Last Suffix        Current Team Position  \
# 425    Aaron Rodgers    Aaron    Rodgers    NaN   Green Bay Packers       QB
# 449   Deshaun Watson  Deshaun     Watson    NaN      Houston Texans       QB
# 407  Patrick Mahomes  Patrick    Mahomes    NaN  Kansas City Chiefs       QB
# 359       Josh Allen     Josh      Allen    NaN       Buffalo Bills       QB
# 444   Ryan Tannehill     Ryan  Tannehill    NaN    Tennessee Titans       QB
#
#        Group  height  weight  birthdate     college  Pass_Yd  QB_rating  \
# 425  Passing    74.0   225.0 1983-12-02  California   4299.0      121.5
# 449  Passing    74.0   221.0 1995-09-14     Clemson   4823.0      112.4
# 407  Passing    75.0   230.0 1995-09-17  Texas Tech   4740.0      108.2
# 359  Passing    77.0   237.0 1996-05-21     Wyoming   4544.0      107.2
# 444  Passing    76.0   207.0 1988-07-27   Texas A&M   3819.0      106.5
#
#      Pass_TD  Rush_Yd  Receive_Yd  Receive_TD  Sacks
# 425     48.0    149.0         NaN         NaN    NaN
# 449     33.0    444.0         NaN         NaN    NaN
# 407     38.0    308.0         NaN         NaN    NaN
# 359     37.0    421.0         NaN         NaN    NaN
# 444     33.0    266.0         NaN         NaN    NaN

# %% [markdown]
# Aaron Rodgers is #1

# %% [markdown]
# ### Rush Rating

# %%
df.sort_values(by=['Rush_Yd'], ascending=False).head()
# Out:
#                Player     First        Last Suffix        Current Team  \
# 509     Derrick Henry   Derrick       Henry    NaN    Tennessee Titans
# 483       Dalvin Cook    Dalvin        Cook    NaN   Minnesota Vikings
# 580   Jonathan Taylor  Jonathan      Taylor    NaN  Indianapolis Colts
# 532       Aaron Jones     Aaron       Jones    NaN   Green Bay Packers
# 549  David Montgomery     David  Montgomery    NaN       Chicago Bears
#
#     Position Group  height  weight  birthdate        college  Pass_Yd  \
# 509       RB  Rush    75.0   247.0 1994-01-04        Alabama      NaN
# 483       RB  Rush    70.0   210.0 1995-08-10  Florida State      NaN
# 580       RB  Rush    70.0   226.0 1999-01-19      Wisconsin      NaN
# 532       RB  Rush    69.0   208.0 1994-12-02  Texas-El Paso      NaN
# 549       RB  Rush    70.0   222.0 1997-06-07     Iowa State      NaN
#
#      QB_rating  Pass_TD  Rush_Yd  Receive_Yd  Receive_TD  Sacks
# 509        NaN      NaN   2027.0       114.0         0.0    NaN
# 483        NaN      NaN   1557.0       361.0         1.0    NaN
# 580        NaN      NaN   1169.0       299.0         1.0    NaN
# 532        NaN      NaN   1104.0       355.0         2.0    NaN
# 549        NaN      NaN   1070.0       438.0         2.0    NaN

# %% [markdown]
# Aaron Jones is #4

# %% [markdown]
# ### Sack Rating

# %%
df.sort_values(by=['Sacks'], ascending=False).head()
# Out:
#                Player    First         Last Suffix         Current Team  \
# 353         T.J. Watt     T.J.         Watt    NaN  Pittsburgh Steelers
# 36       Aaron Donald    Aaron       Donald    NaN     Los Angeles Rams
# 58   Trey Hendrickson     Trey  Hendrickson    NaN   New Orleans Saints
# 100   Yannick Ngakoue  Yannick      Ngakoue    NaN     Baltimore Ravens
# 337    Haason Reddick   Haason      Reddick    NaN    Arizona Cardinals
#
#     Position   Group  height  weight  birthdate           college  Pass_Yd  \
# 353      OLB  Tackle    76.0   252.0 1994-10-11         Wisconsin      NaN
# 36        DE  Tackle    73.0   280.0 1991-05-23        Pittsburgh      NaN
# 58        DE  Tackle    76.0   270.0 1994-12-05  Florida Atlantic      NaN
# 100       DE  Tackle    74.0   246.0 1995-03-31          Maryland      NaN
# 337      OLB  Tackle    73.0   235.0 1994-09-22            Temple      NaN
#
#      QB_rating  Pass_TD  Rush_Yd  Receive_Yd  Receive_TD  Sacks
# 353        NaN      NaN      NaN         NaN         NaN   15.0
# 36         NaN      NaN      NaN         NaN         NaN   13.5
# 58         NaN      NaN      NaN         NaN         NaN   13.5
# 100        NaN      NaN      NaN         NaN         NaN   13.0
# 337        NaN      NaN      NaN         NaN         NaN   12.5

# %% [markdown]
# Aaron Donald is #2

# %% [markdown]
# ### Player Size Visualization

# %%
# Violin plot of player height by position
sns.set(rc={'figure.figsize':(10,8)})
sns.set(color_codes=True)
sns.violinplot( x=df["Position"], y=df["height"], linewidth=2, palette="rocket")
plt.xlabel("Position")
plt.ylabel("Height (in)")
plt.title('Comparing Player Height by Position', fontsize = 16)
plt.show();

# %%
# Violin plot of player weight by position
sns.set(rc={'figure.figsize':(10,8)})
sns.set(color_codes=True)
sns.violinplot( x=df["Position"], y=df["weight"], linewidth=2, palette="rocket")
plt.xlabel("Position")
plt.ylabel("Weight (lbs)")
plt.title('Comparing Player Weight by Position', fontsize = 16)
plt.show();

# %% [markdown]
# ### QB Visualization

# %%
# Plot distribution of QB rating
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(10,8)})
sns.displot(df['QB_rating'], label='QB Rating') # blue dist
plt.title('Distribution of QB Rating')
plt.legend()
plt.show();

# %%
# scatter chart of QB Rating by Pass Yards
sns.relplot(x="Pass_Yd", y="QB_rating", hue="Aaron", 
            size="Aaron", sizes=(100,50), palette=["b", "r"], alpha=.8, height=6, aspect=2, data=df);

# %% [markdown]
# Aaron Rodgers is an outlier on both axes

# %% [markdown]
# ### Rushing Visualization

# %%
# Plot distribution of Rushing Yards
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(10,8)})
sns.displot(df['Rush_Yd'], label='Total Rushing Yards') # blue dist
plt.title('Distribution of Rushing Yards')
plt.legend()
plt.show();

# %%
# scatter chart of Rush Yards
sns.relplot(x="birthdate", y="Rush_Yd", hue="Aaron",  
            size="Aaron", sizes=(100,50), palette=["b", "r"], alpha=.8, height=6, aspect=2, data=df);

# %% [markdown]
# Aaron Jones is #4. Aaron Rodgers also features here (look for the earliest birthdate)

# %% [markdown]
# ### Sacks Visualization

# %%
# Plot distribution of Sacks
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(10,8)})
sns.displot(df['Sacks'], label='Sacks') # blue dist
plt.title('Distribution of Sacks')
plt.legend()
plt.show();

# %%
# scatter chart of Sacks
sns.relplot(x="birthdate", y="Sacks", hue="Aaron",  
            size="Aaron", sizes=(100,50), palette=["b", "r"], alpha=.8, height=6, aspect=2, data=df);

# %% [markdown]
# Aaron Donald is #2. Aaron Lynch also features with one sack.
